# %% [markdown]
# # Constructing Data
# John R. Starr; jrs294@pitt.edu
#
# Created: 12/17/19
# Last edited: 12/17/19

# %% [markdown]
# ## Table of Contents
# This notebook consists of the following sections:
# - [Introduction](#Introduction)
# - [Reading in the Data](#Reading-in-the-Data)
# - [Cleaning the Data](#Cleaning-the-Data)
# - [References](#References)

# %% [markdown]
# ### Introduction
# The purpose of this notebook is to:
# - Open, read, and cite sources of collected poems in preparation of tool construction
# - Separate poems into DataFrame, with each line having:
#     - Original text of poem (str)
#     - Tokenized text of poem (list)
#     - Tokenized set of text of poem (list)
#     - Numbers (both tokenized and tokenized set) (int)
#     - Poet name (str)
#
# To-do:
# - TBD

# %% [markdown]
# Firstly, an examination of the data that we have collected for this project. All texts were taken from [Project Gutenberg](http://www.gutenberg.org/wiki/Main_Page). The files used for the initial version of this project are:
# - _Songs of Innocence_ and _Songs of Experience_ by William Blake (found [here](http://www.gutenberg.org/ebooks/1934))
# - Poems by Emily Dickinson (found [here](http://www.gutenberg.org/ebooks/12242))
# - Poems by T.S. Eliot poems (found [here](http://www.gutenberg.org/ebooks/1567))
# - _Lamia_ by John Keats (found [here](http://www.gutenberg.org/ebooks/2490))
# - Poems by John Keats that were written prior to 1820 (found [here](http://www.gutenberg.org/ebooks/23684))
# - A collection of sonnets written by William Shakespeare (found [here](http://www.gutenberg.org/ebooks/1041))
# - A collection of Alfred Lord Tennyson's early poems (found [here](http://www.gutenberg.org/ebooks/8601))
# - _Leaves of Grass_ by Walt Whitman (found [here](http://www.gutenberg.org/ebooks/1322))
# - Lyrical ballads written by both William Wordsworth & Samuel Taylor Coleridge (found [here](http://www.gutenberg.org/ebooks/9622))
# - Poems and songs written by Robert Burns (found [here](http://www.gutenberg.org/ebooks/1279))
#
# Additional files and their addition date can be found here:
# - TBD

# %% [markdown]
# Now, the notebook will be formatted for ease of use.

# %%
### Formatting IPYNB file ###

# Necessary modules
import pandas as pd
import numpy as np
import nltk
import os

# Turning of pretty-printing
# %pprint

# Prints all outputs without needing a print statement
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# Pretty printing has been turned ON

# %%
path = os.getcwd()

# %% [markdown]
# ### Reading in the Data
# The files will be read in the order listed in the [Introduction](#Introduction).

# %%
# James Blake
a = open(os.path.join(path, 'data', 'blake_songs.txt'), encoding = 'utf-8')
jb = a.read()
a.close()

# %%
jb
# Out:
# '\ufeffSONGS OF INNOCENCE\n\n\nINTRODUCTION\n\n\nPiping down the valleys wild,\n   Piping songs of pleasant glee,\nOn a cloud I saw a child,\n   And he laughing said to me:\n\n‘Pipe a song about a Lamb!’\n   So I piped with merry cheer.\n‘Piper, pipe that song again.’\n   So I piped: he wept to hear.\n\n‘Drop thy pipe, thy happy pipe;\n   Sing thy songs of happy cheer!’\nSo I sung the same again,\n   While he wept with joy to hear.\n\n‘Piper, sit thee down and write\n   In a book, that all may read.’\nSo he vanished from my sight;\n   And I plucked a hollow reed,\n\nAnd I made a rural pen,\n   And I stained the water clear,\nAnd I wrote my happy songs\n   Every child may joy to hear.\n\n\n\nTHE SHEPHERD\n\n\nHow sweet is the shepherd’s sweet lot!\nFrom the morn to the evening he strays;\nHe shall follow his sheep all the day,\nAnd his tongue shall be fillèd with praise.\n\nFor he hears the lambs’ innocent call,\nAnd he hears the ewes’ tender reply;\nHe is watchful while they are in p
# ...
